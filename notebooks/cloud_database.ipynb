# %%
from anta_database import CloudDatabase

db = CloudDatabase()
# Out:
# ...
# ✅ Database downloaded to /tmp/tmp6l5aiygt/AntADatabase.db

# %%
db.query(dataset="Cavitte_2020", flight_id="DC_LDC_DIVIDE")
db.plot.transect_1D()
# Out:
# Formatting ...
